# %%
import pandas as pd
import matplotlib.pyplot as plt

evaluation = [{"instance":[0.010080779809866589,0.00989360924789249,0.007276145889140239,0.009548171127237963],"instance_full":0.028453074448553575,"markov":[0.009812990878166526,0.0028140061513806875,0.0034377893150988256,0.004745896264668367],"markov_full":0.014503567414261473,"regression":[0.0019575506146608753,0.0024579331136759656,0.002310248532583325,0.004146519917555791],"regression_full":0.003985151536357156},{"instance":[0.009519148543593208,0.010330799231187245,0.009980103672556726,0.009732195932830536],"instance_full":0.01219635749209609,"markov":[0.0010289265863001528,0.0027547390212201038,0.010227526211161766,0.0021323245062642437],"markov_full":0.008083454869047536,"regression":[0.0014620196433373551,0.0014266372007613786,0.0017878539323958641,0.0011342510013598605],"regression_full":0.0017199084566222656},{"instance":[0.008259724163676678,0.008031019023138877,0.0072449453993790915,0.010250329159352409],"instance_full":0.010676176800241575,"markov":[0.008259724163676678,0.003094961463410939,0.00930045821451811,0.0032143097727198905],"markov_full":0.006875545857607078,"regression":[0.003909020320882856,0.0025609817387803736,0.002449757094905879,0.0010674346682318433],"regression_full":0.0019725365614526214}]
resulting = []
totals = []

for results in evaluation:
    for i in range(len(results['instance'])):
        resulting.append((results['instance'][i],results['markov'][i],results['regression'][i]))
    df = pd.DataFrame(resulting,columns=['instance', 'markov', 'regression'])
    totals.append((results['instance_full'],results['markov_full'],results['regression_full']))
    df.plot(kind='bar')

df_overall = pd.DataFrame(totals,columns=['instance', 'markov', 'regression'])

df_overall.plot(kind='bar')
