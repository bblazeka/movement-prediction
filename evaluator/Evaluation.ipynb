# %%
import pandas as pd
import matplotlib.pyplot as plt

results = [
    (0.008515350844206406,0.005336527732054635,0.001683004189858138),
    (0.006977571783941869,0.0014032368064649384,0.0028049155080393635),
    (0.005056526475749265,0.0077006660328809585,0.004795546426477872),
    (0.008221385467185195,0.009986062489036818,0.0019015623199806863)
]
df = pd.DataFrame(results,columns=['instance', 'markov', 'regression'])

df.plot(kind='bar')
