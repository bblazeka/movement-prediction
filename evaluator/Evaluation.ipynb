# %%
import pandas as pd
import matplotlib.pyplot as plt

results = [
    (0.0077363737,0.0085571129,0.0035995795),
    (0.0094570197,0.0033914795,0.0020144889),
    (0.0091179064,0.0056896168,0.0048992059),
    (0.0098838954,0.0050211262,0.0015156726)
]

df = pd.DataFrame(results,columns=['instance', 'markov', 'regression'])

df.plot(kind='bar')

# %%
import pandas as pd
import matplotlib.pyplot as plt

overall_results = [(0.01961832664500113, 0.021074058771863666, 0.006302629523696207)]
df_overall = pd.DataFrame(overall_results,columns=['instance', 'markov', 'regression'])

df_overall.plot(kind='bar')
