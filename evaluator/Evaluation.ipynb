# %%
import pandas as pd
import matplotlib.pyplot as plt

results = [
    (0.03337201932420335,0.004176035721823074,0.003599579537919344),
    (0.009457019672177994,0.001728622426964948,0.002014488937773535),
    (0.01086198862041583,0.006993949790711328,0.004899205949434178),
    (0.01961832664500113,0.003914833799153653,0.0015156725689225061)
]
df = pd.DataFrame(results,columns=['instance', 'markov', 'regression'])

df.plot(kind='bar')
